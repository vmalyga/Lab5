

# %% [markdown]
# Зобразіть гістограму $10000$ випадкових величин з бета розподілу з параметрами $a, b, loc, scale$.

# %%
beta_rvs = beta.rvs(a, b, loc=loc, scale=scale, size=1000)
plt.hist(beta_rvs)
plt.show()

# %% [markdown]
# Зобразіть графік функції щільності та нормовану гістограму $100000$ випадкових величин з бета розподілу з параметрами $a, b, loc, scale$. Поексперементуйте з аргументом $bins$ функції `hist`.

# %%
x = np.arange(-1, 2.1, 0.01)
y = beta.pdf(x, a, b, loc=loc, scale=scale)
plt.plot(x, y, 'r')

beta_rvs = beta.rvs(a, b, loc=loc, scale=scale, size=100000)
plt.hist(beta_rvs, normed=True, bins='auto')
plt.show()

# %% [markdown]
# ## 3 Різні параметри

# %% [markdown]
# ### 3.1 Рівномірний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та нормовану гістограму $100000$ випадкових величин з параметром `bins=50` разом з функцією щільності рівномірного розподілу з параметрами:
# 1. $a = 0, b = 2$
# 2. $a = 0, b = 5$
# 3. $a = 0, b = 10$
# 4. $a = -2, b = 2$
# 5. $a = -5, b = 5$
#
# Зробіть шкали на відповідних графіках однаковими для кращого порівняння. Наприклад, усі графіки щільності повинні мати однакові границі як по осі $x$, так і по осі $y$.

# %%
from scipy.stats import uniform

def riv(a, b):
    loc = a
    scale = b - loc
    fig, axs = plt.subplots(1,3, figsize=(20, 5))
    print(fig)
    
    x1 = np.arange(a-1, b+1, 0.01)
    y1 = uniform.pdf(x1, loc=loc, scale=scale)

    axs[0].plot(x1, y1, 'r')
    axs[0].set_title('pdf')
    axs[0].set_ylim(a, b)
    axs[0].set_xlim(a, b)
    y2 = uniform.cdf(x1, loc=loc, scale=scale)

    axs[1].plot(x1, y2, 'g-')
    axs[1].set_title('cdf')
    axs[1].set_ylim(a, b)
    axs[1].set_xlim(a, b)
    unif_rvs = uniform.rvs(loc=loc, scale=scale, size=100000)
    
    axs[2].plot(x1, y1, 'r-.')
    axs[2].set_title('rvs')
    axs[2].hist(unif_rvs, normed=True, bins=50)     
    axs[2].set_ylim(a, b)
    axs[2].set_xlim(a, b)
    plt.show()

riv(0, 2)
riv(0, 5)
riv(0, 10)
riv(-2, 2)
riv(-5, 5)
# Out:
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)

# %% [markdown]
# ### 3.2 Експоненційний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та нормовану гістограму $100000$ випадкових величин з параметром `bins=50` разом з функцією щільності експоненційного розподілу з параметрами:
# 1. $\lambda = 0.1$
# 2. $\lambda = 0.2$
# 3. $\lambda = 0.3$
# 4. $\lambda = 0.4$
# 5. $\lambda = 0.5$
# 6. $\lambda = 0.6$
# 7. $\lambda = 0.7$
# 8. $\lambda = 0.8$
# 9. $\lambda = 0.9$
#
# Зробіть шкали на відповідних графіках однаковими для кращого порівняння. Наприклад, усі графіки щільності повинні мати однакові границі як по осі $x$, так і по осі $y$.

# %%
from scipy.stats import expon

def exp_r(lmd):
    loc = 0
    scale = 1/lmd
    fig, axs = plt.subplots(1, 3, figsize=(20, 5))
    print(fig)
    
    x1 = np.arange(-1, 10, 0.01)
    y1 = expon.pdf(x1, loc=loc, scale=scale)

    axs[0].plot(x1, y1, 'r')
    axs[0].set_title('pdf')
    axs[0].set_ylim(0, 3)
    axs[0].set_xlim(0, 3)
    y2 = expon.cdf(x1, loc=loc, scale=scale)

    axs[1].plot(x1, y2, 'g-')
    axs[1].set_title('cdf')
    axs[1].set_ylim(0, 3)
    axs[1].set_xlim(0, 3)
    expon_rvs = expon.rvs(loc=loc, scale=scale, size=100000)
    
    axs[2].plot(x1, y1, 'r-.')
    axs[2].set_title('rvs')
    axs[2].hist(expon_rvs, normed=True, bins=50)     
    axs[2].set_ylim(0, 3)
    axs[2].set_xlim(0, 3)
    plt.show()

for i in range (1, 10):
    exp_r(i/10)
# Out:
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)

# %% [markdown]
# ### 3.3 Нормальний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та нормовану гістограму $100000$ випадкових величин з параметром `bins=50` разом з функцією щільності нормального розподілу з параметрами:
# 1. $\mu = 0, \sigma = 0.5$
# 2. $\mu = 0, \sigma = 2$
# 3. $\mu = 0, \sigma = 4$
# 4. $\mu = 0, \sigma = 1$
# 5. $\mu = -2, \sigma = 1$
# 6. $\mu = 2, \sigma = 1$
#
# Зробіть шкали на відповідних графіках однаковими для кращого порівняння. Наприклад, усі графіки щільності повинні мати однакові границі як по осі $x$, так і по осі $y$.

# %%
from scipy.stats import norm
def norm_r(mu, sigma):
    loc = mu
    scale = sigma
    fig, axs = plt.subplots(1, 3, figsize=(20, 5))
    print(fig)
    
    x1 = np.arange(-5, 5, 0.01)
    y1 = norm.pdf(x1, loc=loc, scale=scale)

    axs[0].plot(x1, y1, 'r')
    axs[0].set_title('pdf')
    axs[0].set_ylim(-5, 5)
    axs[0].set_xlim(-5, 5)
    y2 = norm.cdf(x1, loc=loc, scale=scale)

    axs[1].plot(x1, y2, 'g-')
    axs[1].set_title('cdf')
    axs[1].set_ylim(-5, 5)
    axs[1].set_xlim(-5, 5)
    norm_rvs = norm.rvs(loc=loc, scale=scale, size=100000)
    
    axs[2].plot(x1, y1, 'r-.')
    axs[2].set_title('rvs')
    axs[2].hist(norm_rvs, normed=True, bins=50)     
    axs[2].set_ylim(-5, 5)
    axs[2].set_xlim (-5, 5)
    plt.show()

norm_r(0, 0.5)
norm_r(0, 2)
norm_r(0, 4)
norm_r(0, 1)
norm_r(-2, 1)
norm_r(2, 1)
# Out:
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)

# %% [markdown]
# ### 3.4 Гамма розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та нормовану гістограму $100000$ випадкових величин з параметром `bins=50` разом з функцією щільності гамма розподілу з параметрами:
# 1. $\alpha = 0.25$
# 2. $\alpha = 0.5$
# 3. $\alpha = 0.75$
# 4. $\alpha = 1$
# 5. $\alpha = 1.5$
# 6. $\alpha = 2$
# 7. $\alpha = 3$
# 8. $\alpha = 5$
# 9. $\alpha = 10$
#
# Зробіть шкали на відповідних графіках однаковими для кращого порівняння. Наприклад, усі графіки щільності повинні мати однакові границі як по осі $x$, так і по осі $y$.

# %%
from scipy.stats import gamma

def G_r(a):
    loc = 0
    scale = 1
    fig, axs = plt.subplots(1, 3, figsize=(20, 5))
    print(fig)
    
    x1 = np.arange(-1, 7, 0.01)
    y1 =  gamma.pdf(x1, a, loc=loc, scale=scale)

    axs[0].plot(x1, y1, 'r')
    axs[0].set_title('pdf')
    axs[0].set_ylim(-1, 7)
    axs[0].set_xlim(-1, 7)
    y2 =  gamma.cdf(x1, a, loc=loc, scale=scale)

    axs[1].plot(x1, y2, 'g-')
    axs[1].set_title('cdf')
    axs[1].set_ylim(-1, 7)
    axs[1].set_xlim(-1, 7)
    gamma_rvs =  gamma.rvs(a, loc=loc, scale=scale, size=100000)
    
    axs[2].plot(x1, y1, 'r-.')
    axs[2].set_title('rvs')
    axs[2].hist( gamma_rvs, normed=True, bins=50)     
    axs[2].set_ylim(-1, 7)
    axs[2].set_xlim (-1, 7)
    plt.show()

G_r(0.25)
G_r(0.5)
G_r(0.75)
G_r(1)
G_r(1.5)
G_r(2)
G_r(3)
G_r(5)
G_r(10)
# Out:
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)
# Figure(1440x360)

# %% [markdown]
# ### 3.5 Логнормальний розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та нормовану гістограму $100000$ випадкових величин з параметром `bins=200` разом з функцією щільності логнормального розподілу з такими параметрами відповідного нормального розподілу:
# 1. $\mu = 0, \sigma = 0.5$
# 2. $\mu = 0, \sigma = 1.5$
# 3. $\mu = 0, \sigma = 2$
# 4. $\mu = 0, \sigma = 1$
# 5. $\mu = -1, \sigma = 1$
# 6. $\mu = 1, \sigma = 1$
#
# Зробіть шкали на відповідних графіках однаковими для кращого порівняння. Наприклад, усі графіки щільності повинні мати однакові границі як по осі $x$, так і по осі $y$.

# %%
from scipy.stats import lognorm 

def logn_r(mu, s):
    loc = 0
    scale = np.exp(mu)
    fig, axs = plt.subplots(1,4, figsize=(20,5))
    print(fig)
    
    x1 = np.arange(-1, 2, 0.01)
    y1 =  lognorm.pdf(x1, s, loc=loc, scale=scale)

    axs[0].plot(x1, y1, 'r')
    axs[0].set_title('pdf')
    axs[0].set_ylim(-1, 2)
    axs[0].set_xlim(-1, 2)
    y2 =  lognorm.cdf(x1, s, loc=loc, scale=scale)

    axs[1].plot(x1, y2, 'g-')
    axs[1].set_title('cdf')
    axs[1].set_ylim(-1, 2)
    axs[1].set_xlim(-1, 2)
    lognorm_rvs =  lognorm.rvs(s, loc=loc, scale=scale, size=10000)
    print(lognorm_rvs)
    
    axs[2].plot(x1, y1, 'r-.')
    axs[2].set_title('rvs')
    axs[2].hist(lognorm_rvs, normed=True, bins='auto')
    axs[3].hist(lognorm_rvs, normed=True, bins=50)
    axs[2].set_ylim(-1, 2)
    axs[2].set_xlim (-1, 2)
    axs[3].plot(x1, y1, 'r-.')
    axs[3].set_ylim(-1, 2)
    axs[3].set_xlim (-1, 2)
    plt.show()

logn_r(0, 0.5)
logn_r(0, 1.5)
logn_r(0, 2)
logn_r(0, 1)
logn_r(-1, 1)
logn_r(1, 1)
# Out:
# Figure(1440x360)
# [0.47485095 1.36788549 1.41292911 ... 0.99613058 0.77175137 1.30300491]
# Figure(1440x360)
# [0.57362965 3.60889961 4.14831591 ... 2.0558346  0.08478459 0.1851954 ]
# Figure(1440x360)
# [4.2034963  0.67963433 0.27589821 ... 0.12501231 2.05820644 1.83669092]
# Figure(1440x360)
# [1.19895995 1.24963738 0.7048467  ... 1.18092497 2.64946125 1.86589659]
# Figure(1440x360)
# [0.10437191 0.83099155 1.4053894  ... 0.27142446 0.03489307 0.39297807]
# Figure(1440x360)
# [10.26701797  2.18635436 39.13324795 ...  0.48279552  7.76315331
#   0.86532947]

# %% [markdown]
# ### 3.6 Бета розподіл

# %% [markdown]
# Зобразіть графічно функцію щільності, функцію розподілу та нормовану гістограму $100000$ випадкових величин з параметром `bins=50` разом з функцією щільності бета розподілу з параметрами:
# 1. $\alpha = 0.5, \beta = 2$
# 2. $\alpha = 0.5, \beta = 1.5$
# 3. $\alpha = 0.5, \beta = 0.5$
# 4. $\alpha = 0.5, \beta = 1$
# 5. $\alpha = 1, \beta = 1$
# 6. $\alpha = 1, \beta = 0.5$
# 7. $\alpha = 1, \beta = 1.5$
# 8. $\alpha = 1, \beta = 2$
# 9. $\alpha = 2, \beta = 2$
# 10. $\alpha = 2, \beta = 5$
# 11. $\alpha = 5, \beta = 2$
# 12. $\alpha = 10, \beta = 10$
#
# Зробіть шкали на відповідних графіках однаковими для кращого порівняння. Наприклад, усі графіки щільності повинні мати однакові границі як по осі $x$, так і по осі $y$.

# %%
from scipy.stats import beta

def b_r(a, b):
    loc = 0
    scale = 1
    fig, axs = plt.subplots(1,4, figsize=(20,5))
    print(fig)
    
    x1 = np.arange(-1, 2, 0.01)
    y1 = beta.pdf(x1, a, b, loc=loc, scale=scale)

    axs[0].plot(x1, y1, 'r')
    axs[0].set_title('pdf')
    axs[0].set_ylim(-1, 2)
    axs[0].set_xlim(-1, 2)
    y2 =  beta.cdf(x1, a, b, loc=loc, scale=scale)

    axs[1].plot(x1, y2, 'g-')
    axs[1].set_title('cdf')
    axs[1].set_ylim(-1, 2)
    axs[1].set_xlim(-1, 2)
    beta_rvs =  beta.rvs(a, b, loc=loc, scale=scale, size=10000)
    print(beta_rvs)
    
    axs[2].plot(x1, y1, 'r-.')
    axs[2].set_title('rvs')
    axs[2].hist(beta_rvs, normed=True, bins='auto')
    axs[3].hist(beta_rvs, normed=True, bins=50)
    axs[2].set_ylim(-1, 2)
    axs[2].set_xlim (-1, 2)
    axs[3].plot(x1, y1, 'r-.')
    axs[3].set_ylim(-1, 2)
    axs[3].set_xlim (-1, 2)
    plt.show()

b_r(0.5, 2)
b_r(0.5, 1.5)
b_r(0.5, 0.5)
b_r(0.5, 1)
b_r(1, 1)
b_r(1, 0.5)
b_r(1, 1.5)
b_r(1, 2)
b_r(2, 2)
b_r(2, 5)
b_r(5, 2)
b_r(10, 10)
# Out:
# Figure(1440x360)
# [0.06508782 0.39366649 0.00177198 ... 0.00226146 0.33897725 0.02962999]
# Figure(1440x360)
# [0.04514929 0.05189967 0.63079394 ... 0.90068186 0.01497505 0.04332234]
# Figure(1440x360)
# [0.72610601 0.86280032 0.24892468 ... 0.56626985 0.85284893 0.12261277]
# Figure(1440x360)
# [3.45015785e-01 2.31582843e-01 5.67398522e-03 ... 2.33721835e-04
#  1.23638001e-01 3.01081975e-02]
# Figure(1440x360)
# [0.13210464 0.60984489 0.46769391 ... 0.2492962  0.57978716 0.00722206]
# Figure(1440x360)
# [0.54970784 0.82657561 0.95640638 ... 0.90911988 0.50782191 0.82711615]
# Figure(1440x360)
# [0.19009393 0.03587673 0.02964013 ... 0.675864   0.28879878 0.13178191]
# Figure(1440x360)
# [4.37711161e-04 3.64963431e-03 5.28725459e-01 ... 6.06613872e-01
#  5.84944971e-01 1.13616232e-01]
# Figure(1440x360)
# [0.87914142 0.35649527 0.31478217 ... 0.62592156 0.97584317 0.25117408]
# Figure(1440x360)
# [0.16325381 0.21740329 0.27215579 ... 0.26258577 0.04800423 0.21050024]
# Figure(1440x360)
# [0.83458052 0.45361971 0.82847619 ... 0.64880325 0.52738577 0.69860293]
# Figure(1440x360)
# [0.55683811 0.76283383 0.47652607 ... 0.65359104 0.46842288 0.41519266]

# %% [markdown]
# ## 4 Апроксимація біноміального розподілу нормальним розподілом

# %% [markdown]
# Покажіть схожість біноміального розподілу та нормального розподілу з відповідними параметрами:
# - $n = 100, p = 0.05$
# - $n = 100, p = 0.1$
# - $n = 100, p = 0.15$
# - $n = 100, p = 0.2$
# - $n = 100, p = 0.35$
# - $n = 100, p = 0.5$
# - $n = 100, p = 0.75$
#
# Зобразіть графіки їх функцій щільності (обидві функції на одному графіку) та функцій розподілу (обидві функції на другому графіку) на двох сабплотах в одному рядку.
#
# **Зауваження.** Математичне сподівання та дисперсія відповідного нормального розподілу збігається з математичним сподіванням та дисперсією біноміального розподілу.

# %%
from scipy.stats import norm
from scipy.stats import binom

n=100
list_p = [0.05, 0.1, 0.15, 0.2, 0.35, 0.5, 0.75]
for p in list_p:
    mu = n*p 
    sigma = (n*p*(1-p))**0.5
    loc = mu
    scale = sigma
    x2 = np.arange(0, 100, 0.1)
    x2g = np.arange(0, 100, 1)
    y2 = norm.pdf(x2, loc=loc, scale=scale)
    y2_ =norm.cdf(x2, loc=loc, scale=scale)
    fig, axs = plt.subplots(1,2, figsize=(20,5))
    yg = binom.pmf(x2g, n, p)
    yg_ = binom.cdf(x2g, n, p)
    
    axs[0].plot(x2, y2, 'r--', x2g, yg, 'y')
    axs[0].set_title('pdf')
    axs[1].plot(x2, y2_, 'r--', x2g, yg_, 'y')
    axs[1].set_title('cdf')

# %% [markdown]
# ## 5 Апроксимація числа $\pi$

# %% [markdown]
# Розглянемо квадрат зі стороною $2a$. Нехай коло радіуса $a$ вписане в цей квадрат. Якщо вибрати точку рівномірно з цього квадрата, то ймовірність, що ця точка також належить і вписаному колу, дорівнює відношенню площ кола та квадрата, тобто $\pi a^2/(2a)^2 = \pi/4$.
#
# Реалізуйте функцію емпіричної апроксимації числа $\pi$ за $n$ симуляцій (вибору $n$ випадкових точок з квадрата). Зобразіть графічно отримані елементи: квадрат, коло, випадкові точки. Виділіть точки, що належать колу, окремим кольором від інших точок.
#
# Нехай $a = 1$. Виведіть результат функції для:
# 1. $n = 10$
# 2. $n = 100$
# 3. $n = 500$
# 4. $n = 1000$
# 5. $n = 2000$

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import uniform
n = [10, 100, 500, 1000, 2000]
a = 1
loc = 0
scale = 2 * a
x = np.arange(0, 2*a, 0.001)
for i in n:
    print("n =",i)
    circle = 0
    square = 0
    plt.figure(figsize=(10, 10))
    plt.subplot(1, 1, 1)
    plt.plot(x, 1 + np.sqrt(a**2 - (x-1)**2), 'p')
    plt.plot(x, 1 - np.sqrt(a**2 - (x-1)**2), 'p')
    for j in range(i):
        y = uniform.rvs(loc=loc, scale=scale, size=2)
        if (y[0] - 1) ** 2 + (y[1] - 1) ** 2 <= a ** 2:
            circle += 1
            square += 1
            plt.plot([y[0]], [y[1]], 'r.')
        else:
            square += 1
            plt.plot([y[0]], [y[1]], 'k.')
    plt.show()
    print(f'π ≈ {4 * circle / square}')
# Out:
# n = 10
# π ≈ 3.2
# n = 100
# π ≈ 3.08
# n = 500
# π ≈ 3.176
# n = 1000
# π ≈ 3.184
# n = 2000
# π ≈ 3.134
